# %%
import pandas as pd

chemicalDf = pd.read_excel("./storetLabeled.xlsx")
mainDf = pd.read_file("./chemical.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     260         try:
# --> 261             import xlrd
#     262         except ImportError:
#
# ImportError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-417e91b6a605> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 chemicalDf = pd.read_excel("./storetLabeled.xlsx")
#       4 mainDf = pd.read_file("./chemical.xlsx")
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     261             import xlrd
#     262         except ImportError:
# --> 263             raise ImportError(err_msg)
#     264         else:
#     265             ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ImportError: Install xlrd >= 0.9.0 for Excel support

# %%
mainDf.head()
# waterData['PARAMETER'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-811b5f01a991> in <module>()
# ----> 1 mainDf.head()
#       2 # waterData['PARAMETER'].unique()
#
# NameError: name 'mainDf' is not defined

# %%
import pandas as pd
import numpy as np
watsysDf = pd.read_csv("./watsys.csv", encoding='cp1252')
watsysDf = watsysDf[watsysDf.ADDRESS.notnull()]

print((watsysDf.loc[watsysDf['ADDRESS'] != None]))
# Out:
#       SYSTEM_NO                                SYSTEM_NAM  \
# 0       2800064                         DAKOTA SHY WINERY
# 1       5403214                                       NaN
# 2       4000829                         VINES R.V. RESORT
# 3       0103039              MOHRLAND MUTUAL WATER SYSTEM
# 4       0103040       NORRIS CANYON PROPERTY OWNERS ASSN.
# 5       0103041            TRAILER HAVEN MOBILE HOME PARK
# 9       0104001     WASHINGTON HOSPITAL HEALTHCARE SYSTEM
# 12      0104004                    U. S. PIPE AND FOUNDRY
# 14      0104010                       MORTON SALT COMPANY
# 15      0104012         VULCAN MATERIALS, CALMAT DIVISION
# 16      0104013                 PLEASANTON GRAVEL COMPANY
# 17      0104014                  HOSANNA HOMES - INACTIVE
# 18      0105002                         RIVERS END MARINA
# 19      0105003                         CEMEX/ELIOT PLANT
# 20      0105004                     MOUNTAIN HOUSE SCHOOL
# 21      0105006        HANSON AGGREGATE MID-PACIFIC, INC.
# 22      0105008          CASTLEWOOD DOMESTIC WATER SYSTEM
# 23      0105009                     MOUNTAIN HOUSE SCHOOL
# 24      0105010           EBRPD - DEL VALLE REGIONAL PARK
# 25      0105011       EBRPD - SHADOW CLIFFS REGIONAL PARK
# 27      0105013      EBRPD - REDWOOD SPRING REGIONAL PARK
# 28      0105014               EBRPD - GARIN REGIONAL PARK
# 29      0105015    EBRPD - MISSION PEAK REGIONAL PRESERVE
# 30      0105016                        MOUNTAIN HOUSE BAR
# 31      0105017                RANCHO LOS MOCHOS-BSA CAMP
# 32      0105018                  PURPLE ORCHID RESORT SPA
# 33      0105020                ALAMEDA COUNTY FAIRGROUNDS
# 34      0105021                MOUNTAIN HOUSE GOLF COURSE
# 35      0110001             ALAMEDA COUNTY WATER DISTRICT
# 36      0110003      CALIFORNIA WATER SERVICE - LIVERMORE
# 34                     MOUNTAIN HOUSE              15000 Altamont Pass Rd
# 35                     ALAMEDA COUNTY                       P.O. Box 5110
# 36                      CWS LIVERMORE                  195 South N Street
# ...                               ...                                 ...
# 15023                             NaN                   49762 HAMILTON RD
# 15024                             NaN        24387 W. Whitesbridge Avenue
# 15025                    P.O. Box 232                12841 Sonoma Highway
# 15026                             NaN           41893 YOKOHL VALLEY DRIVE
# 15027                             NaN                  1280 Scales Street
# 15028                             NaN                   54895 FILLMORE ST
# 15029                             NaN                602 S Tippecanoe Ave
# 15030                             NaN              5061 E. Soda Rock Lane
# 15031                             NaN             1220 N Street, Room 116
# 15032                             NaN                   709 Dutton Street
# 15033                             NaN                      34614 Avenue 9
# 15034                             NaN                       39303 ROAD 56
# 15035                             NaN                    7310 Pacific Ave
# 15036                             NaN                   23185 Summit Road
# 15037                             NaN                         P.O.Box 653
# 15038                             NaN           12295 Old Redwood Highway
# 15039                             NaN           675 TEXAS STREET STE 2500
# 15040                             NaN                       18463 Road 23
# 15041                             NaN                   5200 Di Arie Road
# 15042                             NaN  475 Aviation Boulevard - Suite 120
# 15043                             NaN                     33502 Lerdo Hwy
# 15044                             NaN                42134 Happer Lake Rd
# 15045                             NaN                42134 Happer Lake Rd
# 15046                             NaN                14165 N BECKMAN ROAD
# 15047                             NaN                     10151 Florin Rd
# 15048                             NaN                     3004 ANDRADE RD
# 15050                             NaN                           PO BOX 61
# 15051                             NaN              8000 PLEASANT GROVE RD
# 15052                             NaN                         42675 Rd 44
# 15053                             NaN                  20404 TAFT HIGHWAY
#
#                  CITY STATE    ZIP ZIP_EXT  POP_SERV  CONNECTION  \
# 0          ST. HELENA    CA  94574     NaN      30.0         1.0
# 1        THREE RIVERS    CA  93271     NaN      25.0         2.0
# 2             PASO RO    CA  93446     NaN     400.0         1.0
# 3             HAYWARD    CA  94545      tt     116.0        99.0
# 4       CASTRO VALLEY    CA  94552       S      50.0        19.0
# 5         SAN LEANDRO    CA  94577    6058     543.0       200.0
# 9             FREMONT    CA  94538     538       0.0         1.0
# 12         UNION CITY    CA  94587    rich       0.0         0.0
# 14             NEWARK    CA  94560     560      10.0         1.0
# 15          LIVERMORE    CA  94551     551      45.0         3.0
# 16         PLEASANTON    CA  94566     566      26.0         4.0
# 17      CASTRO VALLEY    CA  94552    9698       0.0         2.0
# 18      DISCOVERY BAY    CA  94505    1951     250.0         4.0
# 19         PLEASANTON    CA  94566    6308      70.0         1.0
# 20             CARMEL    CA  93923     NaN       0.0         0.0
# 21         PLEASANTON    CA  94566     566      78.0         1.0
# 22         PLEASANTON    CA  94566     NaN     499.0       194.0
# 23              BYRON    CA  94514     NaN      24.0         3.0
# 24          LIVERMORE    CA  94605     605   10000.0       101.0
# 25         PLEASANTON    CA  94566     566     593.0         2.0
# 27            OAKLAND    CA  94605     605      35.0         6.0
# 28            HAYWARD    CA  94544     544      40.0         7.0
# 29            OAKLAND    CA  94605    0381      10.0         1.0
# 30              TRACY    CA  95391    9210      25.0         1.0
# 31              TRACY    CA  95391    9602     600.0         1.0
# 32          Livermore    CA  94550     NaN      45.0         0.0
# 33         PLEASANTON    CA  94566    7001      82.0         3.0
# 34     MOUNTAIN HOUSE    CA  95391     NaN       0.0         1.0
# 35            FREMONT    CA  94537     537  340000.0     82487.0
# 36          LIVERMORE    CA  94550    4350   56700.0     18043.0
# ...               ...   ...    ...     ...       ...         ...
# 15023      CLARKSBURG    CA  95612     NaN     225.0         4.0
# 15024          KERMAN    CA  93630     NaN      95.0         2.0
# 15025      GLEN ELLEN    CA  95442     NaN      50.0         2.0
# 15026     SPRINGVILLE    CA  93265     NaN      25.0         1.0
# 15027      MARYSVILLE    CA  95901     NaN       0.0         1.0
# 15028         THERMAL    CA  92274     NaN     126.0         1.0
# 15029  SAN BERNARDINO    CA  92408     NaN     100.0         1.0
# 15030      HEALDSBURG    CA  95448     NaN      35.0         1.0
# 15031      SACRAMENTO    CA  95814     NaN       1.0         1.0
# 15032         WINTERS    CA  95694     NaN      50.0         5.0
# 15033          MADERA    CA  93636     NaN     152.0         2.0
# 15034          DINUBA    CA  93618     NaN      30.0         3.0
# 15035  PLEASANT GROVE    CA  95668     NaN      25.0         1.0
# 15036       LOS GATOS    CA  95033     NaN      40.0         1.0
# 15037         KENWOOD    CA  95452     NaN      40.0         3.0
# 15038      HEALDSBURG    CA  95448     NaN      26.0         1.0
# 15039       FAIRFIELD    CA  94533     NaN      30.0         1.0
# 15040          MADERA    CA  93637     NaN     500.0         1.0
# 15041        Mt Aukum    CA  95656     NaN      25.0         5.0
# 15042      SANTA ROSA    CA  95403     NaN      32.0         1.0
# 15043     BAKERSFIELD    CA  93308     NaN     120.0         1.0
# 15044         HINKLEY    CA  92347     NaN      25.0         1.0
# 15045         HINKLEY    CA  92347     NaN      25.0         1.0
# 15046            LODI    CA  95240     NaN     300.0         6.0
# 15047      SACRAMENTO    CA  95829     NaN    1500.0       300.0
# 15048           SUNOL    CA  94586    9453     155.0         1.0
# 15050    EMIGRANT GAP    CA  95715     NaN      25.0         1.0
# 15051         ELVERTA    CA  95626     NaN      25.0         1.0
# 15052         REEDLEY    CA  93654     NaN      25.0         1.0
# 15053     BAKERSFIELD    CA  93311     NaN      25.0         1.0
#
#                                   AREA_SERVE
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5              Trailer Haven Mobilehome Park
# 9      Washington Hospital Healthcare System
# 12                                       NaN
# 14                       Morton Salt Company
# 15             Vulcan Materials, CalMat Div.
# 16                                       NaN
# 17                              Verne Teyler
# 18                                       NaN
# 19         RMC-Lonestar Eliot Agregate Plant
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                             Josie Alvarez
# 31                                       NaN
# 32                                       NaN
# 33                Alameda County Fairgrounds
# 34                Mountain House Golf Course
# 35                 FREMONT NEWARK,UNION CITY
# 36                                 LIVERMORE
# ...                                      ...
# 15023                                    NaN
# 15024                                    NaN
# 15025                                    NaN
# 15026                                    NaN
# 15027                   WASTEWATER GENERATOR
# 15028                                    NaN
# 15029                                    NaN
# 15030                                    NaN
# 15031                                    NaN
# 15032                                    NaN
# 15033                                    NaN
# 15034                                    NaN
# 15035                                    NaN
# 15036                                    NaN
# 15037                                    NaN
# 15038                                    NaN
# 15039                                    NaN
# 15040                                    NaN
# 15041                                    NaN
# 15042                                    NaN
# 15043                                    NaN
# 15044                                    NaN
# 15045                                    NaN
# 15046                                    NaN
# 15047                                    NaN
# 15048                                    NaN
# 15050                                    NaN
# 15051                                    NaN
# 15052                                    NaN
# 15053                                    NaN
#
# [13374 rows x 11 columns]
